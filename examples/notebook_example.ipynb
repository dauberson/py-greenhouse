# %%
import os
import pandas as pd
os.chdir("/usr/app/src")
import numpy as np
import data_sourcing, data_preprocessing, data_splitting, feature_extraction,modeling
from sklearn import metrics
import nltk
import eli5
from eli5.lime import TextExplainer
import joblib
from eli5 import show_weights
from eli5 import show_prediction
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
df = data_sourcing.get("/usr/app/examples/data_example.csv", ";", 0, ["text","cats"])
df.head()
# Out:
#                                                 text      cats
# 0  � @ Governador Valadares, Minas Gerais https:/...    Neutro
# 1  �� @ Governador Valadares, Minas Gerais https:...    Neutro
# 2                        ��� https://t.co/BnDsO34qK0    Neutro
# 3  ��� PSOL vai questionar aumento de vereadores ...  Negativo
# 4  " bom é bandido morto"\nDeputado Cabo Júlio é ...    Neutro

# %%
df["clean_text"] = data_preprocessing.clean(df, text_col = "text")
df.head()
# Out:
#                                                 text      cats  \
# 0  � @ Governador Valadares, Minas Gerais https:/...    Neutro
# 1  �� @ Governador Valadares, Minas Gerais https:...    Neutro
# 2                        ��� https://t.co/BnDsO34qK0    Neutro
# 3  ��� PSOL vai questionar aumento de vereadores ...  Negativo
# 4  " bom é bandido morto"\nDeputado Cabo Júlio é ...    Neutro
#
#                                           clean_text
# 0   governador valadares minas gerais https co b3...
# 1   governador valadares minas gerais https co dp...
# 2                                https co bndso34qk0
# 3   psol vai questionar aumento de vereadores pre...
# 4   bom é bandido morto deputado cabo júlio é con...

# %%
df["tokens"] = df["clean_text"].apply(feature_extraction.tokenizer("multi_word"))
df.head()
# Out:
#                                                 text      cats  \
# 0  � @ Governador Valadares, Minas Gerais https:/...    Neutro
# 1  �� @ Governador Valadares, Minas Gerais https:...    Neutro
# 2                        ��� https://t.co/BnDsO34qK0    Neutro
# 3  ��� PSOL vai questionar aumento de vereadores ...  Negativo
# 4  " bom é bandido morto"\nDeputado Cabo Júlio é ...    Neutro
#
#                                           clean_text  \
# 0   governador valadares minas gerais https co b3...
# 1   governador valadares minas gerais https co dp...
# 2                                https co bndso34qk0
# 3   psol vai questionar aumento de vereadores pre...
# 4   bom é bandido morto deputado cabo júlio é con...
#
#                                               tokens
# 0  [governador, valadares, minas, gerais, https, ...
# 1  [governador, valadares, minas, gerais, https, ...
# 2                            [https, co, bndso34qk0]
# 3  [psol, vai, questionar, aumento, de, vereadore...
# 4  [bom, é, bandido, morto, deputado, cabo, júlio...

# %%
df["tokens_wosw"] = data_preprocessing.stop_words(df, token_col = "tokens")
df.head()
# Out:
#                                                 text      cats  \
# 0  � @ Governador Valadares, Minas Gerais https:/...    Neutro
# 1  �� @ Governador Valadares, Minas Gerais https:...    Neutro
# 2                        ��� https://t.co/BnDsO34qK0    Neutro
# 3  ��� PSOL vai questionar aumento de vereadores ...  Negativo
# 4  " bom é bandido morto"\nDeputado Cabo Júlio é ...    Neutro
#
#                                           clean_text  \
# 0   governador valadares minas gerais https co b3...
# 1   governador valadares minas gerais https co dp...
# 2                                https co bndso34qk0
# 3   psol vai questionar aumento de vereadores pre...
# 4   bom é bandido morto deputado cabo júlio é con...
#
#                                               tokens  \
# 0  [governador, valadares, minas, gerais, https, ...
# 1  [governador, valadares, minas, gerais, https, ...
# 2                            [https, co, bndso34qk0]
# 3  [psol, vai, questionar, aumento, de, vereadore...
# 4  [bom, é, bandido, morto, deputado, cabo, júlio...
#
#                                          tokens_wosw
# 0  [governador, valadares, minas, gerais, https, ...
# 1  [governador, valadares, minas, gerais, https, ...
# 2                            [https, co, bndso34qk0]
# 3  [psol, vai, questionar, aumento, vereadores, p...
# 4  [bom, bandido, morto, deputado, cabo, júlio, c...

# %%
df["num_cat"] = data_preprocessing.label_encoding(df, y_col = "cats")
df.head()
# Out:
#                                                 text      cats  \
# 0  � @ Governador Valadares, Minas Gerais https:/...    Neutro
# 1  �� @ Governador Valadares, Minas Gerais https:...    Neutro
# 2                        ��� https://t.co/BnDsO34qK0    Neutro
# 3  ��� PSOL vai questionar aumento de vereadores ...  Negativo
# 4  " bom é bandido morto"\nDeputado Cabo Júlio é ...    Neutro
#
#                                           clean_text  \
# 0   governador valadares minas gerais https co b3...
# 1   governador valadares minas gerais https co dp...
# 2                                https co bndso34qk0
# 3   psol vai questionar aumento de vereadores pre...
# 4   bom é bandido morto deputado cabo júlio é con...
#
#                                               tokens  \
# 0  [governador, valadares, minas, gerais, https, ...
# 1  [governador, valadares, minas, gerais, https, ...
# 2                            [https, co, bndso34qk0]
# 3  [psol, vai, questionar, aumento, de, vereadore...
# 4  [bom, é, bandido, morto, deputado, cabo, júlio...
#
#                                          tokens_wosw  num_cat
# 0  [governador, valadares, minas, gerais, https, ...        1
# 1  [governador, valadares, minas, gerais, https, ...        1
# 2                            [https, co, bndso34qk0]        1
# 3  [psol, vai, questionar, aumento, vereadores, p...        0
# 4  [bom, bandido, morto, deputado, cabo, júlio, c...        1

# %%
train, valid, test = data_splitting.split(df, train_ratio=0.8, valid_ratio=0.1, test_ratio=0.1)
print(len(df))
print(len(train))
print(len(valid))
print(len(test))
# Out:
# 8127
# 6502
# 812
# 813

# %%
model = modeling.model("1")
vec = model.vectorizing("count", "split")
model_id = model.fit(train, "cats", "clean_text")
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END model=RandomForestClassifier(random_state=1), model__max_depth=28.0; total time=   0.9s
# [CV] END model=RandomForestClassifier(random_state=1), model__max_depth=28.0; total time=   0.9s
# [CV] END model=RandomForestClassifier(random_state=1), model__max_depth=28.0; total time=   0.9s
# [CV] END model=RandomForestClassifier(random_state=1), model__max_depth=28.0; total time=   0.9s
# [CV] END model=RandomForestClassifier(random_state=1), model__max_depth=28.0; total time=   0.9s
# [CV] END model=RandomForestClassifier(random_state=1), model__max_depth=4.0; total time=   0.4s
# [CV] END model=RandomForestClassifier(random_state=1), model__max_depth=4.0; total time=   0.4s
# [CV] END model=RandomForestClassifier(random_state=1), model__max_depth=4.0; total time=   0.4s
# [CV] END model=RandomForestClassifier(random_state=1), model__max_depth=4.0; total time=   0.4s
# [CV] END model=RandomForestClassifier(random_state=1), model__max_depth=4.0; total time=   0.4s
# [CV] END model=RandomForestClassifier(random_state=1), model__max_depth=23.0; total time=   0.7s
# [CV] END model=RandomForestClassifier(random_state=1), model__max_depth=23.0; total time=   0.8s
# [CV] END model=RandomForestClassifier(random_state=1), model__max_depth=23.0; total time=   0.8s
# [CV] END model=RandomForestClassifier(random_state=1), model__max_depth=23.0; total time=   0.7s
# [CV] END model=RandomForestClassifier(random_state=1), model__max_depth=23.0; total time=   0.7s
# [CV] END model=RandomForestClassifier(random_state=1), model__max_depth=19.0; total time=   0.6s
# [CV] END model=RandomForestClassifier(random_state=1), model__max_depth=19.0; total time=   0.6s
# [CV] END model=RandomForestClassifier(random_state=1), model__max_depth=19.0; total time=   0.6s
# [CV] END model=RandomForestClassifier(random_state=1), model__max_depth=19.0; total time=   0.6s
# [CV] END model=RandomForestClassifier(random_state=1), model__max_depth=19.0; total time=   0.6s
# [CV] END model=RandomForestClassifier(random_state=1), model__max_depth=24.0; total time=   0.8s
# [CV] END model=RandomForestClassifier(random_state=1), model__max_depth=24.0; total time=   0.8s
# [CV] END model=RandomForestClassifier(random_state=1), model__max_depth=24.0; total time=   0.8s
# [CV] END model=RandomForestClassifier(random_state=1), model__max_depth=24.0; total time=   0.6s
# [CV] END model=RandomForestClassifier(random_state=1), model__max_depth=24.0; total time=   0.7s
# [CV] END model=RandomForestClassifier(random_state=1), model__max_depth=18.0; total time=   0.6s
# [CV] END model=RandomForestClassifier(random_state=1), model__max_depth=18.0; total time=   0.5s
# [CV] END model=RandomForestClassifier(random_state=1), model__max_depth=18.0; total time=   0.7s
# [CV] END model=RandomForestClassifier(random_state=1), model__max_depth=18.0; total time=   0.6s
# [CV] END model=RandomForestClassifier(random_state=1), model__max_depth=18.0; total time=   0.5s
# [CV] END model=RandomForestClassifier(random_state=1), model__max_depth=22.0; total time=   0.6s
# [CV] END model=RandomForestClassifier(random_state=1), model__max_depth=22.0; total time=   0.6s
# [CV] END model=RandomForestClassifier(random_state=1), model__max_depth=22.0; total time=   0.6s
# [CV] END model=RandomForestClassifier(random_state=1), model__max_depth=22.0; total time=   0.6s
# [CV] END model=RandomForestClassifier(random_state=1), model__max_depth=22.0; total time=   0.6s
# [CV] END model=RandomForestClassifier(random_state=1), model__max_depth=29.0; total time=   0.8s
# [CV] END model=RandomForestClassifier(random_state=1), model__max_depth=29.0; total time=   0.8s
# [CV] END model=RandomForestClassifier(random_state=1), model__max_depth=29.0; total time=   0.8s
# [CV] END model=RandomForestClassifier(random_state=1), model__max_depth=29.0; total time=   0.8s
# [CV] END model=RandomForestClassifier(random_state=1), model__max_depth=29.0; total time=   0.8s
# [CV] END model=RandomForestClassifier(random_state=1), model__max_depth=20.0; total time=   0.6s
# [CV] END model=RandomForestClassifier(random_state=1), model__max_depth=20.0; total time=   0.6s
# [CV] END model=RandomForestClassifier(random_state=1), model__max_depth=20.0; total time=   0.6s
# [CV] END model=RandomForestClassifier(random_state=1), model__max_depth=20.0; total time=   0.6s
# [CV] END model=RandomForestClassifier(random_state=1), model__max_depth=20.0; total time=   0.6s
# [CV] END model=RandomForestClassifier(random_state=1), model__max_depth=15.0; total time=   0.5s
# [CV] END model=RandomForestClassifier(random_state=1), model__max_depth=15.0; total time=   0.5s
# [CV] END model=RandomForestClassifier(random_state=1), model__max_depth=15.0; total time=   0.5s
# [CV] END model=RandomForestClassifier(random_state=1), model__max_depth=15.0; total time=   0.5s
# [CV] END model=RandomForestClassifier(random_state=1), model__max_depth=15.0; total time=   0.5s

# %%
model.eli5()
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0583
#
#                     &plusmn; 0.1565
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 estado
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 81.95%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0504
#
#                     &plusmn; 0.1836
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 helicópteros
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 86.85%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0320
#
#                     &plusmn; 0.1529
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 calamidade
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 88.83%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0254
#
#                     &plusmn; 0.1092
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 financeira
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 89.78%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0224
#
#                     &plusmn; 0.0903
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 governo
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 90.66%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0196
#
#                     &plusmn; 0.0924
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 compra
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 90.90%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0189
#
#                     &plusmn; 0.0720
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 rt
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 90.93%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0188
#
#                     &plusmn; 0.0836
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 drogas
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 91.50%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0172
#
#                     &plusmn; 0.0821
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 dois
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 92.18%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0152
#
#                     &plusmn; 0.0566
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 co
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 92.68%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0139
#
#                     &plusmn; 0.0497
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 pimentel
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 92.85%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0134
#
#                     &plusmn; 0.0433
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 que
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 93.35%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0121
#
#                     &plusmn; 0.0457
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 https
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 93.42%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0119
#
#                     &plusmn; 0.0437
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 em
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 93.65%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0113
#
#                     &plusmn; 0.0560
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 mais
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 93.97%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0105
#
#                     &plusmn; 0.0352
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 valadares
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.18%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0100
#
#                     &plusmn; 0.0450
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 roubo
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.57%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0091
#
#                     &plusmn; 0.0367
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.

# %%
import spacy
import pandas as pd
import numpy as np

# %%
from spacy.lang.pt.stop_words import STOP_WORDS

# %%
nlp = spacy.load("pt_core_news_sm")

# %%
import string
punctuations = string.punctuation
punctuations
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
from spacy.lang.pt import Portuguese
parser = Portuguese()

# %%
stopwords = list(STOP_WORDS)

# %%
def spacy_tokenizer(sentence):
    mytokens = parser(sentence)
    mytokens = [ word.lemma_.lower().strip() if word.lemma_ != "-PRON-" else word.lower_ for word in mytokens ]
    mytokens = [ word for word in mytokens if word not in stopwords and word not in punctuations ]
    return mytokens

# %%
# ex1 = "Felipe Castanhari esta no podcast do flow e o papo esta muito bom"
ex1 = "He was walking with the walker in the Wall he may had sat and run with the runner"

# %%
spacy_tokenizer(ex1)
# Out:
# []

# %%
import joblib
from eli5.sklearn import explain_weights_sklearn
from eli5.formatters import format_as_dataframe, format_as_dataframes
te = TextExplainer(random_state=42)
loaded_model = joblib.load('/usr/app/models/1.joblib')

te.fit("dasd a",loaded_model.predict_proba)
# te.show_prediction(target_names=model.named_steps["vec"].get_feature_names())
format_as_dataframe(explain_weights_sklearn(loaded_model, feature_names=loaded_model.named_steps["vec"].get_feature_names(), top=10))
# Out:
#         feature    weight       std
# 0        estado  0.058291  0.078267
# 1  helicópteros  0.050356  0.091794
# 2    calamidade  0.032039  0.076448
# 3    financeira  0.025352  0.054609
# 4       governo  0.022350  0.045167
# 5        compra  0.019631  0.046214
# 6            rt  0.018914  0.035989
# 7        drogas  0.018822  0.041795
# 8          dois  0.017164  0.041051
# 9            co  0.015248  0.028294

# %%
te = TextExplainer(random_state=42)
te.fit("deu bom", loaded_model.predict_proba)
te.show_prediction(target_names=loaded_model.named_steps["vec"].get_feature_names())
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=00
#
# </b>
#
#
#     (probability <b>0.042</b>, score <b>-3.353</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 96.26%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.281
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -3.073
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="background-color: hsl(0, 100.00%, 61.17%); opacity: 0.99" title="-1.504">deu</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 60.00%); opacity: 1.00" title="-1.569">bom</span>
#     </p>
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=000
#
# </b>
#
#
#     (probability <b>0.594</b>, score <b>-0.097</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 99.34%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.024
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 98.54%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.073
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="background-color: hsl(0, 100.00%, 95.32%); opacity: 0.81" title="-0.073">deu</span><span style="opacity: 0.80"> bom</span>
#     </p>
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=01
#
# </b>
#
#
#     (probability <b>0.364</b>, score <b>-0.888</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 98.49%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.076
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 92.13%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.811
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="background-color: hsl(0, 100.00%, 84.44%); opacity: 0.85" title="-0.407">deu</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 84.53%); opacity: 0.85" title="-0.404">bom</span>
#     </p>
